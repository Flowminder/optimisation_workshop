# %% [markdown]
# <img src="img/f_blue@2x.png" width="15%" align="left"/>
#
# <br></br>
#
# # Data driven decision making using a rapid optimal service placement solution
# ---
# *26 April 2022* \
# **Author**: Alistair Steward \@ Flowminder foundation
#
# <br></br>
#
# XXXX
#
# **The problem:** XXXX

# %% [markdown]
# # rewrite
#
#
# ## Getting started
# ---
# ### Exercise Overview
# ---
# Using geospatial analysis in Python, this demo will show an assessment of health facility coverage for maternal health using the GRID3 population data for Kaduna State.
#
# In this exercise we are going to:
#
# - Load some spatial data
# - Subset the data to focus on points of interest
# - Aggregate dataset using some basic geospatial techniques
# - Try and identify connections between datasets to set targets

# %% [markdown]
# ### Loading Packages
# ---

# %%
# General purpose libraries.
import pandas as pd
import os
import numpy as np

# Geospatial libraries.
import geopandas as gpd
import rioxarray
import rasterio
from rasterio.plot import show
import folium
# Voronoi and Zonal statistics libraries
from rasterstats import zonal_stats

# Visualization libraries.
from IPython.display import display
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors

# %%
# notes
#Kaduna total: 10847178.027184606
#Kaduna new sites: 6562328.11129499
#Kaduna existing sites: 4284850

# %% [markdown]
# ### Loading Datasets
# We have four datasets used in this example:
#
# These datasets can be obtained from the GRID3 Nigeria Data portal at https://grid3.gov.ng/
#
# >- [**Health facility locations**](https://grid3.gov.ng/dataset/kaduna-health-care-facilities-primary-secondary-and-tertiary/resources)
# >- [**Ward boundaries**](https://grid3.gov.ng/dataset/kaduna-operational-ward-boundaries)
# >- [**Gridded population**](https://grid3.gov.ng/dataset/national-population-estimates/resources)\
# We provide an already prepared dataset with women aged 15-49 for Kaduna State
# >- [**State boundary**](https://grid3.gov.ng/dataset/kaduna-state-administrative-boundaries)

# %%
# Path for the data folder
data_path = os.path.join(os.getcwd(), 'data')

# Load population
population =  rioxarray.open_rasterio(os.path.join(data_path, str('NGA_population_v2_0_gridded.tif')))

# Load boundaries
state_boundaries = gpd.read_file(data_path + '/GRID3_NGA_State_Boundaries/NGA_State_Boundaries.shp')

# Load existing healthcare facilities
health_sites = gpd.read_file(data_path + '/NGA_COVAX_PHCs_Hospitals_20210408.gdb', 
                           layer = 'COVAX_NGA_matched_PHCs_20210408')

# filter to Kaduna
kaduna_boundary = state_boundaries.loc[state_boundaries['state_name'] == 'Kaduna']
kaduna_existing_sites = health_sites.loc[health_sites['states'] == 'Kaduna']

# filter to relevant columns
kaduna_existing_sites = kaduna_existing_sites[['facility', '_intro_geo_longitude', 
                                               '_intro_geo_latitude', 
                                               'lgas', 'Wards', 'geometry']]

# %%
kaduna_existing_sites['longitude'] = kaduna_existing_sites['_intro_geo_longitude']

# %%
kaduna_existing_sites['latitude'] = kaduna_existing_sites['_intro_geo_latitude']

# %%
kaduna_existing_sites= kaduna_existing_sites.reset_index(drop=True)

# %%
kaduna_existing_sites = kaduna_existing_sites[['facility', 'longitude', 
                                               'latitude', 
                                               'lgas', 'Wards', 'geometry']]

# %%
kaduna_existing_sites.to_file(data_path + '/kaduna_existing_sites.geojson')

# %%
kaduna_boundary = kaduna_boundary.reset_index(drop=True)

# %%
kaduna_boundary.to_file(data_path + '/kaduna_boundary.geojson')

# %% [markdown]
# ### Existing coverage

# %%
#Define coordinates of where we want to center our map
boulder_coords = [10.48650018, 7.42406665]

#Create the map
my_map = folium.Map(location = boulder_coords, zoom_start = 8)

folium.GeoJson(kaduna_boundary).add_to(my_map)

#folium.Circle(kaduna_existing_sites).add_to(my_map)

folium.Circle(location=kaduna_existing_sites, color='crimson', fill=False,).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [41], line 11
#       7 folium.GeoJson(kaduna_boundary).add_to(my_map)
#       9 #folium.Circle(kaduna_existing_sites).add_to(my_map)
# ---> 11 folium.Circle(location=kaduna_existing_sites, color='crimson', fill=False,).add_to(m)
#
# File ~\miniconda3\envs\irc-reach-gis_clone\lib\site-packages\folium\vector_layers.py:265, in Circle.__init__(self, location, radius, popup, tooltip, **kwargs)
#     264 def __init__(self, location=None, radius=50, popup=None, tooltip=None, **kwargs):
# --> 265     super(Circle, self).__init__(location, popup=popup, tooltip=tooltip)
#     266     self._name = 'circle'
#     267     self.options = path_options(line=False, radius=radius, **kwargs)
#
# File ~\miniconda3\envs\irc-reach-gis_clone\lib\site-packages\folium\map.py:280, in Marker.__init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     278 super(Marker, self).__init__()
#     279 self._name = 'Marker'
# --> 280 self.location = validate_location(location) if location else None
#     281 self.options = parse_options(
#     282     draggable=draggable or None,
#     283     autoPan=draggable or None,
#     284     **kwargs
#     285 )
#     286 if icon is not None:
#
# File ~\miniconda3\envs\irc-reach-gis_clone\lib\site-packages\pandas\core\generic.py:1526, in NDFrame.__nonzero__(self)
#    1524 @final
#    1525 def __nonzero__(self) -> NoReturn:
# -> 1526     raise ValueError(
#    1527         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1528         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1529     )
#
# ValueError: The truth value of a GeoDataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
kaduna_existing_sites
# Out:
#                       facility          lgas           Wards  \
# 3979      Health Clinic Gwanda  Birnin Gwari          Damari
# 3980           Funtuwan Badadi  Birnin Gwari      Dogon Dawa
# 3981                 H C KWAGA  Birnin Gwari           Gayam
# 3982  Health Clinic Sabon Layi  Birnin Gwari         Kakangi
# 3983             PHC Kutemeshi  Birnin Gwari       Kutemeshi
# ...                        ...           ...             ...
# 4225    Health clinic Dandutse         Zaria      Tudun Wada
# 4226           H/c Tudun jukun         Zaria     Tukur Tukur
# 4227      Kafan kibo  H/clinic         Zaria  Unguwar Fatika
# 4228              Alfadarai Hc         Zaria    Unguwar Juma
# 4229                    Aba HC         Zaria        Wuciciri
#
#                       geometry
# 3979  POINT (7.04518 11.06819)
# 3980  POINT (7.08825 11.03690)
# 3981  POINT (6.62737 10.71010)
# 3982  POINT (6.35725 10.65003)
# 3983  POINT (7.11689 11.17696)
# ...                        ...
# 4225  POINT (7.71897 11.08291)
# 4226  POINT (7.70460 11.09665)
# 4227  POINT (7.69458 11.07667)
# 4228  POINT (7.69436 11.05355)
# 4229  POINT (7.76110 11.02066)
#
# [251 rows x 4 columns]

# %%
#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_
# 14        15  sv_boundary_states.fid-65d4c550_169d91acef3_3f63  MULTIPOLYGON
# 15        16  sv_boundary_states.fid-65d4c550_169d91acef3_3f6c  MULTIPOLYGON
# 16        17  sv_boundary_states.fid-65d4c550_169d91acef3_3f72  MULTIPOLYGON
# 17        18  sv_boundary_states.fid-65d4c550_169d91acef3_3f77  MULTIPOLYGON
# 18        19  sv_boundary_states.fid-65d4c550_169d91acef3_3f7c  MULTIPOLYGON
# 19        20  sv_boundary_states.fid-65d4c550_169d91acef3_3f80  MULTIPOLYGON
# 20        21  sv_boundary_states.fid-65d4c550_169d91acef3_3f8c  MULTIPOLYGON
# 21        22  sv_boundary_states.fid-65d4c550_169d91acef3_3f91  MULTIPOLYGON
# 22        23  sv_boundary_states.fid-65d4c550_169d91acef3_3f96  MULTIPOLYGON
# 23        24  sv_boundary_states.fid-65d4c550_169d91acef3_3f98  MULTIPOLYGON
# 24        25  sv_boundary_states.fid-65d4c550_169d91acef3_3f9b  MULTIPOLYGON
# 25        26  sv_boundary_states.fid-65d4c550_169d91acef3_3f9f  MULTIPOLYGON
# 26        27  sv_boundary_states.fid-65d4c550_169d91acef3_3fa3  MULTIPOLYGON
# 27        28  sv_boundary_states.fid-65d4c550_169d91acef3_3fa8  MULTIPOLYGON
# 28        29  sv_boundary_states.fid-65d4c550_169d91acef3_3fab  MULTIPOLYGON
# 29        30  sv_boundary_states.fid-65d4c550_169d91acef3_3fae  MULTIPOLYGON
# 30        31  sv_boundary_states.fid-65d4c550_169d91acef3_3fb2  MULTIPOLYGON
# 31        32  sv_boundary_states.fid-65d4c550_169d91acef3_3fb5  MULTIPOLYGON
# 32        33  sv_boundary_states.fid-65d4c550_169d91acef3_3fb9  MULTIPOLYGON
# 33        34  sv_boundary_states.fid-65d4c550_169d91acef3_3fbc  MULTIPOLYGON
# 34        35  sv_boundary_states.fid-65d4c550_169d91acef3_3fbe  MULTIPOLYGON
# 35        36  sv_boundary_states.fid-65d4c550_169d91acef3_3fc1  MULTIPOLYGON
# 36        37  sv_boundary_states.fid-65d4c550_169d91acef3_3fc4  MULTIPOLYGON
#
#    state_code   state_name     capital_ci  \
# 0          SO       Sokoto         Sokoto
# 1          GO        Gombe          Gombe
# 2          AD      Adamawa           Yola
# 3          ZA      Zamfara          Gusau
# 4          YO         Yobe       Damaturu
# 5          BR        Borno      Maiduguri
# 6          AK    Akwa Ibom            Uyo
# 7          BA       Bauchi         Bauchi
# 8          OG         Ogun       Abeokuta
# 9          NI        Niger          Minna
# 10         AN      Anambra           Awka
# 11         KN         Kano           Kano
# 12         NA     Nasarawa          Lafia
# 13         KB        Kebbi   Birnin Kebbi
# 14         KD       Kaduna         Kaduna
# 15         KT      Katsina        Katsina
# 16         PL      Plateau            Jos
# 17         ED          Edo     Benin City
# 18         OY          Oyo        Ibandan
# 19         JI       Jigawa          Dutse
# 20         CR  Cross River        Calabar
# 21         TA       Taraba        Jalingo
# 35       None    0.308116    4.340368    4.340368    0.308116
# 36       None    0.530156    4.422133    4.422133    0.530156
#
#                                              geometry
# 0   POLYGON ((4.63265 11.67143, 4.62886 11.66810, ...
# 1   POLYGON ((10.96913 9.61535, 10.96932 9.61550, ...
# 2   POLYGON ((12.20157 8.10679, 12.20152 8.10679, ...
# 3   POLYGON ((6.57204 11.02215, 6.57237 11.02276, ...
# 4   POLYGON ((11.71435 10.63409, 11.70572 10.63111...
# 5   POLYGON ((11.98919 10.03755, 11.97055 10.03494...
# 6   POLYGON ((7.54124 4.73247, 7.53394 4.75336, 7....
# 7   POLYGON ((9.57922 9.55167, 9.57816 9.54280, 9....
# 8   POLYGON ((4.59755 6.36057, 4.59757 6.35688, 4....
# 9   POLYGON ((6.76434 8.30751, 6.76427 8.30747, 6....
# 10  POLYGON ((6.86365 5.74933, 6.86324 5.74965, 6....
# 11  POLYGON ((7.80552 11.37170, 7.80512 11.37171, ...
# 12  POLYGON ((7.62491 8.02953, 7.58347 8.03769, 7....
# 13  POLYGON ((5.39667 11.02606, 5.38899 11.03747, ...
# 14  POLYGON ((8.57775 9.49924, 8.58013 9.49558, 8....
# 15  POLYGON ((7.14427 11.13012, 7.13381 11.13537, ...
# 16  POLYGON ((9.85053 8.42207, 9.84106 8.41617, 9....
# 17  POLYGON ((6.10050 5.80169, 6.09374 5.79412, 6....
# 18  POLYGON ((3.99896 7.12657, 3.99755 7.12617, 3....
# 19  POLYGON ((9.85782 11.02319, 9.85687 11.02590, ...
# 20  POLYGON ((8.46125 4.75542, 8.46014 4.75542, 8....
# 21  POLYGON ((11.26160 6.43338, 11.21415 6.43623, ...
# 22  MULTIPOLYGON (((7.21913 4.38398, 7.21444 4.382...
# 23  POLYGON ((5.60547 7.47319, 5.60391 7.46780, 5....
# 24  POLYGON ((9.66416 6.93569, 9.64570 6.89482, 9....
# 25  POLYGON ((6.28354 5.27060, 6.28383 5.26650, 6....
# 26  MULTIPOLYGON (((4.51951 6.34103, 4.50686 6.313...
# 27  POLYGON ((5.00457 7.41393, 5.00438 7.41318, 5....
# 28  POLYGON ((5.29907 8.00767, 5.29778 8.00767, 5....
# 29  POLYGON ((7.38548 5.50336, 7.38477 5.50151, 7....
# 30  POLYGON ((6.71704 6.55009, 6.68392 6.54312, 6....
# 31  POLYGON ((7.47943 4.92413, 7.47872 4.91954, 7....
# 32  POLYGON ((7.47762 8.63133, 7.44303 8.59328, 7....
# 33  POLYGON ((6.13651 4.27485, 6.11583 4.27306, 6....
# 34  POLYGON ((7.53338 6.01098, 7.52006 6.02002, 7....
# 35  POLYGON ((3.02077 6.39705, 3.00694 6.39661, 2....
# 36  POLYGON ((7.59936 5.95737, 7.61311 5.95198, 7....

# %%
# map existing health facilities and population for whole country

# %%
# add new sites (100% coverage)

# %%
# coverage curve

# %%
# choose some thresholds

# %%
# map new sites with priority levels (focus on one area?)
